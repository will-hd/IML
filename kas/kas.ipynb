# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from argparse import Namespace
import sys
import os
from loss import ELBOLoss
from torch.utils.data import DataLoader
sys.path.append(os.getcwd())
from data_utils import get_dataloader
# from dataset.datasets import NewRegression
import numpy as np
import random
from tqdm import tqdm
import torch

from temp_data import Temperatures
from informed_nps import INP
from plot import plot_predictive


config = Namespace(
    input_dim=1,
    output_dim=1,
    xy_encoder_num_hidden=2,
    xy_encoder_hidden_dim=128,
    data_agg_func='sum',
    latent_encoder_num_hidden=2,
    decoder_hidden_dim=64,
    decoder_num_hidden=2,
    decoder_activation='gelu',
    hidden_dim=128,
    x_transf_dim=128,
    x_encoder_num_hidden=1,
    test_num_z_samples=32,
    train_num_z_samples=1,
    knowledge_extractor_num_hidden=0,
    knowledge_extractor_hidden_dim=128,
    knowledge_dropout=0,
    knowledge_dim=128,
    knowledge_merge='self-attention',
    text_encoder = 'roberta',
    use_knowledge=False,
    freeze_llm=True,
    tune_llm_layer_norms=False,
    freeze_meta_networks=False,
    # dataset
    batch_size=64,
    min_num_context=3,
    max_num_context=20,
    x_sampler='random-uniform-25',
    noise=0,
    # reproducibility
    seed=44,
    dataset='temperatures',
    knowledge_type='desc',
    num_targets=50,
    path='latent'
    #xy_self_attention='dot',
)
config.device = "cuda"

train_dataset = Temperatures(split='train')
val_dataset = Temperatures(split='train')
test_dataset = Temperatures(split='train')
# dataset = NewRegression(root='data/new', split='train')
#dataset = CelebA(root='data', split='train', knowledge_type='set')
# dataset = metaMIMIC(config, split='train', root='data/metaMIMIC', knowledge_type='none')
# train_dataloader = get_dataloader(dataset, config)
# config.num_classes = dataset.num_classes
#dataset = SetKnowledgeTrendingSinusoids(split='train', root='data/toy-regression', knowledge_type='masked')
train_dataloader = get_dataloader(train_dataset, config)
val_dataloader = get_dataloader(val_dataset, config)
test_config = config
test_config.batch_size = 1
test_dataloader = get_dataloader(test_dataset, test_config)
# train_dataloader = DataLoader(dataset, batch_size=64, shuffle=True)
#config.knowledge_input_dim = dataset.knowledge_input_dim

model = INP(config).to(config.device)
print(model)
print(sum(p.numel() for p in model.parameters() if p.requires_grad))
loss_func = ELBOLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

torch.manual_seed(config.seed)
np.random.seed(config.seed)
random.seed(config.seed)

epoch_losses = []
for epoch in range(1000):
    epoch_loss = 0
    num_batches = len(train_dataloader)

    for i, batch in enumerate(train_dataloader):
        optimizer.zero_grad()
        
        context, target, knowledge, _ = batch
        # print(len(knowledge))
        # print(context.shape)
        # print(knowledge.shape)
        x_context, y_context = context
        x_target, y_target = target
        x_context = x_context.to(config.device)
        y_context = y_context.to(config.device)
        x_target = x_target.to(config.device)
        y_target = y_target.to(config.device)
    
        if config.use_knowledge:
            outputs = model(x_context, y_context, x_target, y_target, knowledge)
        else:
            outputs = model(x_context, y_context, x_target, y_target, None)
    
        p_yCc = outputs[0]
    
        loss = loss_func(outputs, y_target)
        epoch_loss += loss["loss"].item()

        loss["loss"].backward()
        optimizer.step()
    epoch_losses.append(epoch_loss/num_batches)
    print(f"ep: {epoch}, avg_epoch_loss: {epoch_loss/num_batches}")

    if epoch % 10 == 0:
        with torch.no_grad():
            num_val_epochs = 1
            avg_val_epoch_loss = 0
            avg_val_nll = 0
            num_val_batches = len(val_dataloader)
            
            for _ in range(num_val_epochs):
                # model.training = False
                val_epoch_loss = 0
                val_epoch_nll = 0
                for i, batch in enumerate(val_dataloader):
                
                    context, target, knowledge, _ = batch
                    # print(len(knowledge))
                    # print(context.shape)
                    # print(knowledge.shape)
                    x_context, y_context = context
                    x_target, y_target = target
                    x_context = x_context.to(config.device)
                    y_context = y_context.to(config.device)
                    x_target = x_target.to(config.device)
                    y_target = y_target.to(config.device)
                
                    if config.use_knowledge:
                        outputs = model(x_context, y_context, x_target, y_target, knowledge)
                    else:
                        outputs = model(x_context, y_context, x_target, y_target, None)
                
                    p_yCc = outputs[0]
                
                    val_loss = loss_func(outputs, y_target)
                    val_epoch_loss += val_loss["loss"].item() / num_val_batches
                    val_epoch_nll += val_loss["log_p"].item() / num_val_batches
                avg_val_epoch_loss += val_epoch_loss / num_val_epochs
                avg_val_nll += val_epoch_nll / num_val_epochs
            print(f"ep: {epoch}, Validation Loss: {avg_val_epoch_loss}, NLL: {avg_val_nll}")
            # model.training = True
        
        # plot
        for j, batch in enumerate(test_dataloader):
            context, target, knowledge, _ = batch
            x_context, y_context = context
            x_target, y_target = target
            print(len(knowledge))
            x_context = x_context.to(config.device)
            y_context = y_context.to(config.device)
            x_target = x_target.to(config.device)
            y_target = y_target.to(config.device)
            plot_predictive(model, x_context, y_context, x_target, y_target, knowledge, config)
            break
        # probs = outputs[0].probs
        # predictions = torch.tensor(probs > 0.5, dtype=torch.float32)
        # accuracy = (predictions == y_target).float().mean()
    
        # print(accuracy)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INP(
#   (xy_encoder): XYEncoder(
#     (pairer): MLP(
#       (layers): ModuleList(
#         (0): Linear(in_features=129, out_features=128, bias=True)
#         (1-2): 2 x Linear(in_features=128, out_features=128, bias=True)
#       )
#       (activation): GELU(approximate='none')
#     )
#   )
#   (latent_encoder): ModulatedLatentEncoder(
#     (encoder): MLP(
#       (layers): ModuleList(
#         (0-1): 2 x Linear(in_features=128, out_features=128, bias=True)
#         (2): Linear(in_features=128, out_features=256, bias=True)
#       )
#       (activation): GELU(approximate='none')
#     )
#     (knowledge_encoder): ModulatingKnowledgeEncoder(
#       (text_encoder): RoBERTa(
#         (llm): RobertaModel(
#           (embeddings): RobertaEmbeddings(
#             (word_embeddings): Embedding(50265, 768, padding_idx=1)
#             (position_embeddings): Embedding(514, 768, padding_idx=1)
#             (token_type_embeddings): Embedding(1, 768)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (encoder): RobertaEncoder(
#             (layer): ModuleList(
#               (0-11): 12 x RobertaLayer(
#                 (attention): RobertaAttention(
#                   (self): RobertaSelfAttention(
#                     (query): Linear(in_features=768, out_features=768, bias=True)
#                     (key): Linear(in_features=768, out_features=768, bias=True)
#                     (value): Linear(in_features=768, out_features=768, bias=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                   (output): RobertaSelfOutput(
#                     (dense): Linear(in_features=768, out_features=768, bias=True)
#                     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                     (dropout): Dropout(p=0.1, inplace=False)
#                   )
#                 )
#                 (intermediate): RobertaIntermediate(
#                   (dense): Linear(in_features=768, out_features=3072, bias=True)
#                   (intermediate_act_fn): GELUActivation()
#                 )
#                 (output): RobertaOutput(
#                   (dense): Linear(in_features=3072, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#             )
#           )
#           (pooler): RobertaPooler(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (activation): Tanh()
#           )
#         )
#       )
#       (knowledge_extractor): MLP(
#         (layers): ModuleList(
#           (0): Linear(in_features=896, out_features=256, bias=True)
#           (1): Linear(in_features=256, out_features=512, bias=True)
#         )
#         (activation): GELU(approximate='none')
#       )
#     )
#   )
#   (decoder): Decoder(
#     (mlp): MLP(
#       (layers): ModuleList(
#         (0): Linear(in_features=256, out_features=64, bias=True)
#         (1): Linear(in_features=64, out_features=64, bias=True)
#         (2): Linear(in_features=64, out_features=2, bias=True)
#       )
#       (activation): GELU(approximate='none')
#     )
#   )
#   (x_encoder): XEncoder(
#     (mlp): MLP(
#       (layers): ModuleList(
#         (0): Linear(in_features=1, out_features=128, bias=True)
#         (1): Linear(in_features=128, out_features=128, bias=True)
#       )
#       (activation): GELU(approximate='none')
#     )
#   )
# )
# 1105026
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 0, avg_epoch_loss: 477031.4306640625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 0, Validation Loss: 79486.3564453125, NLL: 67529.47900390625
# 1
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 1, avg_epoch_loss: 88111.79296875
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 2, avg_epoch_loss: 96403.0
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 3, avg_epoch_loss: 75384.451171875
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 4, avg_epoch_loss: 67527.68115234375
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 5, avg_epoch_loss: 65259.00927734375
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 6, avg_epoch_loss: 62903.8134765625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 7, avg_epoch_loss: 60249.458984375
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 8, avg_epoch_loss: 58240.6142578125
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 9, avg_epoch_loss: 56560.53564453125
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 10, avg_epoch_loss: 54755.00732421875
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 10, Validation Loss: 54207.35986328125, NLL: 50611.3818359375
# 1
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 11, avg_epoch_loss: 53688.5009765625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 12, avg_epoch_loss: 52188.28515625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 13, avg_epoch_loss: 50739.11083984375
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 14, avg_epoch_loss: 49597.4482421875
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 15, avg_epoch_loss: 48664.01611328125
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 16, avg_epoch_loss: 47748.88134765625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 17, avg_epoch_loss: 46729.52734375
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 18, avg_epoch_loss: 45981.4873046875
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 19, avg_epoch_loss: 45159.5068359375
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 20, avg_epoch_loss: 44589.3232421875
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 20, Validation Loss: 44130.6845703125, NLL: 42497.79736328125
# 1
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 21, avg_epoch_loss: 43957.19140625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 22, avg_epoch_loss: 43400.77685546875
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 23, avg_epoch_loss: 42910.44140625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 24, avg_epoch_loss: 42522.0458984375
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 25, avg_epoch_loss: 42012.38525390625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 26, avg_epoch_loss: 41543.0595703125
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 27, avg_epoch_loss: 40980.951171875
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 28, avg_epoch_loss: 40607.697265625
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 29, avg_epoch_loss: 40155.142578125
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 30, avg_epoch_loss: 39709.3359375
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 59, 288])
# torch.Size([1])
# ep: 30, Validation Loss: 39448.53173828125, NLL: 38492.64013671875
# 1
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# torch.Size([1, 64, 288])
# torch.Size([1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 93
#      90 epoch_loss = 0
#      91 num_batches = len(train_dataloader)
# ---> 93 for i, batch in enumerate(train_dataloader):
#      94     optimizer.zero_grad()
#      96     context, target, knowledge, _ = batch
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /home/w/IML/kas/temp_data.py:58, in Temperatures.__getitem__(self, idx)
#      56     knowledge = torch.tensor(knowledge, dtype=torch.float32)
#      57 elif self.knowledge_type == 'desc':
# ---> 58     knowledge = self.knowledge_df.iloc[k_idx, :].description
#      59 else:
#      60     raise NotImplementedError
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1692, in _iLocIndexer._getitem_tuple(self, tup)
#    1690 tup = self._validate_tuple_indexer(tup)
#    1691 with suppress(IndexingError):
# -> 1692     return self._getitem_lowerdim(tup)
#    1694 return self._getitem_tuple_same_dim(tup)
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1062, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1059 tup = self._validate_key_length(tup)
#    1061 for i, key in enumerate(tup):
# -> 1062     if is_label_like(key):
#    1063         # We don't need to check for tuples here because those are
#    1064         #  caught by the _is_nested_tuple_indexer check above.
#    1065         section = self._getitem_axis(key, axis=i)
#    1067         # We should never have a scalar section here, because
#    1068         #  _getitem_lowerdim is only called after a check for
#    1069         #  is_scalar_access, which that would be.
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:2747, in is_label_like(key)
#    2739 """
#    2740 Returns
#    2741 -------
#    2742 bool
#    2743 """
#    2744 # select a label or row
#    2745 return (
#    2746     not isinstance(key, slice)
# -> 2747     and not is_list_like_indexer(key)
#    2748     and key is not Ellipsis
#    2749 )
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/pandas/core/indexers/utils.py:62, in is_list_like_indexer(key)
#      39     """
#      40     Check if a slice object can be interpreted as a positional indexer.
#      41
#    (...)
#      53     depending on the index being sliced.
#      54     """
#      55     return (
#      56         lib.is_int_or_none(slc.start)
#      57         and lib.is_int_or_none(slc.stop)
#      58         and lib.is_int_or_none(slc.step)
#      59     )
# ---> 62 def is_list_like_indexer(key) -> bool:
#      63     """
#      64     Check if we have a list-like indexer that is *not* a NamedTuple.
#      65
#    (...)
#      72     bool
#      73     """
#      74     # allow a list_like, but exclude NamedTuples which can be indexers
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.plot(epoch_losses)
plt.ylim(bottom=0, top=0.1e6)
# Out:
# (0.0, 100000.0)

# %%
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.normal import Normal
from torch.distributions.independent import Independent

loc = torch.randn(1, 64, 288, 1)
scale = torch.abs(torch.randn(1, 64, 288, 1))

# mvn = MultivariateNormal(loc, scale_tril=torch.diag(scale))
normal = Normal(loc, scale)
diagn = Independent(Normal(loc, scale), 1)

target = torch.randn(64, 288, 1)
# print(mvn.batch_shape, mvn.event_shape)
# print(mvn.log_prob(target))
print(normal.log_prob(target))
print(normal.log_prob(target).shape)
print(normal.log_prob(target).sum(dim=(-1, -2)))
print(normal.batch_shape, normal.event_shape)

print(diagn.log_prob(target))
print(diagn.log_prob(target).shape)
print(diagn.log_prob(target).sum(dim=-1))
print(diagn.log_prob(target).sum(dim=-1).shape)
print(diagn.batch_shape, diagn.event_shape)
# Out:
# tensor([[[[-8.0718e+00],
#           [-2.0211e+00],
#           [-2.7700e+01],
#           ...,
#           [-1.8111e+00],
#           [-5.7215e+02],
#           [-1.7846e+00]],
#
#          [[-8.7546e+00],
#           [-4.8846e-01],
#           [-1.2620e+00],
#           ...,
#           [-1.6435e+04],
#           [-2.8456e-01],
#           [-1.3199e+01]],
#
#          [[-1.4663e+00],
#           [-1.5914e+00],
#           [-1.1465e+00],
#           ...,
#           [-1.8884e+01],
#           [-1.5523e+00],
#           [-9.4274e-01]],
#
#          ...,
#
#          [[-1.5821e+00],
#           [-3.7636e+00],
#           [-5.5700e+01],
#           ...,
#           [-4.4776e+01],
#           [-3.7308e+01],
#           [-1.5371e+00]],
#
#          [[ 5.4952e-01],
#           [-2.0759e+00],
#           [-7.5943e+00],
#           ...,
#           [-4.3264e+00],
#           [-2.9236e-01],
#           [-6.1717e+01]],
#
#          [[-1.6673e+00],
#           [-2.0342e+00],
#           [-1.1290e+00],
#           ...,
#           [-2.5668e+00],
#           [-1.4310e+00],
#           [-2.4188e+00]]]])
# torch.Size([1, 64, 288, 1])
# tensor([[-1.8002e+07, -3.6932e+05, -3.3784e+04, -9.8653e+03, -2.0240e+05,
#          -3.4787e+04, -4.1503e+04, -4.8302e+07, -1.0468e+07, -1.6142e+04,
#          -1.7028e+05, -1.7272e+05, -3.8270e+04, -2.6949e+05, -3.2626e+05,
#          -1.5800e+05, -4.7606e+04, -6.4736e+04, -1.5969e+05, -4.1177e+04,
