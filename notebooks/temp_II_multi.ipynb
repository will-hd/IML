# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import torch
import torch.nn as nn
from torch.distributions import Normal
from torch.distributions.kl import kl_divergence
import sys
sys.path.append('..')

import logging
from src.utils import setup_logging
setup_logging(console=True, file=False, debug=True)
logger = logging.getLogger(__name__)
# Out:
# [INFO]: Logging setup completed at 07-08-2024-220215        (utils.py:62 [22:02:15])

# %%
import pandas as pd
from data.tempdata import TempData
import matplotlib.pyplot as plt
# Load the data
data_path = '../data/data_with_desc.csv'
data = pd.read_csv(data_path, header=None)
data_test = TempData(data=data, max_num_context=10, device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu"))

temporary_batch_size = 1
batch = data_test.generate_batch(batch_size=temporary_batch_size, split='train', return_knowledge=True)

fig = plt.figure()
print(batch.knowledge)
for i in range(temporary_batch_size):
    x_target = batch.x_target[i].flatten()
    y_target = batch.y_target[i].flatten()
    plt.plot(x_target.numpy(), y_target.numpy(), 'k:')
# for i in range(temporary_batch_size):
#     x_context = batch.x_context[i].flatten()
#     y_context = batch.y_context[i].flatten()
#     plt.scatter(x_context.numpy(), y_context.numpy())
plt.xlim(-2, 2)
    # Formatting the x-axis to display time in "HHMM" format
plt.xticks(list(x_target[::36])+ [2.0], labels=["0000", "0300", "0600", "0900", "1200", "1500", "1800", "2100", "2400"])

# Label axes
plt.xlabel('Time (HHMM)')
plt.ylabel('Temperature (°C)')

# fig.savefig('../figures/temperature_sample1', dpi=300)
plt.show()
# Out:
# ['The night will start off very chilly at -7.4 degrees and will gradually warm up to -4.6 degrees by late evening. The coldest period will be early morning, while the warmest will be in the late evening.']

# %%
def eval(model, data, num_context=None):
    model.training = False
    with torch.no_grad():
        test_loss = 0
        n_test_batches = 128
        test_batch_size = 96
        for _ in range(n_test_batches):
            batch = data.generate_batch(batch_size=test_batch_size,
                                    device=DEVICE,
                                    return_knowledge=True,
                                    split='test',
                                    num_context=num_context)
            
            p_y_pred, q_z_context, q_z_target = model(batch.x_context,
                                                  batch.y_context,
                                                  batch.x_target,
                                                  batch.y_target,
                                                  batch.knowledge)
            test_loss_dict = loss_function(p_y_pred, q_z_context, None, batch.y_target)
            test_loss += test_loss_dict["loss"].item() / n_test_batches
        # val_losses.append(val_loss)
        
    model.training = True
    return test_loss
# Out:
# 1
# INP Test loss 794.7987322807312
# NP Test loss 1892.1638941764832
#
# 2
# INP Test loss 595.1955602169037
# NP Test loss 1327.082308292389
#
# 3
# INP Test loss 516.5564250946045
# NP Test loss 986.4298303127289
#
# 4
# INP Test loss 455.2862160205841
# NP Test loss 806.871363401413
#
# 5
# INP Test loss 442.1821942329407
# NP Test loss 784.7961740493774
#
# 6
# INP Test loss 442.6123070716858
# NP Test loss 676.6968324184418
#
# 7
# INP Test loss 437.27793860435486
# NP Test loss 598.4665694236755
#
# 8
# INP Test loss 428.0025722980499
# NP Test loss 573.4859144687653
#
# 9
# INP Test loss 417.523912191391
# NP Test loss 576.5094826221466
#
# 10
# INP Test loss 417.1806299686432
# NP Test loss 551.1761620044708

# %%
from src.plot import plot_predictive
from src.informed_np import InformedNeuralProcess
from tqdm import tqdm
# from src.loss import ELBOLoss
from src.loss import ELBOLoss

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
logging.info(f'Using DEVICE: {DEVICE}')

USE_KNOWLEDGE = True
logging.info(f'USE_KNOWLEDGE: {USE_KNOWLEDGE}')

x_dim = 1
y_dim = 1
determ_dim = 128  # Dimension of representation of context points
latent_dim = 128  # Dimension of sampled latent variable
hidden_dim = 128  # Dimension of hidden layers in encoder and decoder

optimiser = torch.optim.Adam(model.parameters(), lr=1e-3)
logging.info(f'Using optimiser Adam')
loss_function = ELBOLoss(beta=1, reduction='mean')

from src.train import train    

AVG_LOSS_PRINT_INTERVAL = 250
PLOT_SAMPLE_INTERVAL = 1000
MAX_ITERS = 4500

data_path = '../data/data_with_desc.csv'
data = pd.read_csv(data_path, header=None)
data = TempData(data=data , max_num_context=10, device=DEVICE)

inp_test_losses = []
np_test_losses = []

for _ in range(5):
    # init new model
    model = InformedNeuralProcess(
        x_dim=x_dim,
        y_dim=y_dim,
        hidden_dim=hidden_dim,
        latent_dim=latent_dim,
        determ_dim=determ_dim,
        knowledge_dim=128,
        mlps_activation=nn.GELU(),
        x_proj_dim=1,
        n_h_layers_x_proj=0,
        n_h_layers_decoder=4,
        n_h_layers_latent_xy_encoder=3,
        n_h_layers_film_latent_encoder=3,
        path='latent',
        train_num_z_samples=4,
        test_num_z_samples=32,
        use_bias=True,
        user_context_in_target=True, # TODO investigate
        use_latent_self_attn=True,
        # use_determ_self_attn=True,
        # use_determ_cross_attn=True,
        use_knowledge=USE_KNOWLEDGE,
        knowledge_dropout=0.3,
        roberta_return_cls=True,
        tune_llm_layer_norms=True,
        freeze_llm=True,
        knowledge_projection_n_h_layers=0,
        knowledge_aggregation_method='FiLM+MLP',
        device='cuda',
        beta=1.0
    ).to(DEVICE)

    model, optimiser, train_losses, val_losses = train(model=model,
                                                   data=data,
                                                   loss_function=loss_function,
                                                   optimiser=optimiser,
                                                   device=DEVICE,
                                                   use_knowledge=USE_KNOWLEDGE,
                                                   max_iters=MAX_ITERS,
                                                   avg_loss_print_interval=AVG_LOSS_PRINT_INTERVAL,
                                                   plot_sample_interval=PLOT_SAMPLE_INTERVAL)
# Out:
# [INFO]: Using DEVICE: cuda:0        (4206479968.py:8 [00:33:42])
# [INFO]: USE_KNOWLEDGE: True        (4206479968.py:11 [00:33:42])
# [WARNING]: Hidden activation set but no hidden layers        (mlp.py:22 [00:33:42])
# [WARNING]: Hidden activation set but no hidden layers        (mlp.py:22 [00:33:42])
# [DEBUG]: XYEncoder has x_dim=1 and y_dim=1        (xy_encoders.py:57 [00:33:42])
# [DEBUG]: Resetting dropped connection: huggingface.co        (connectionpool.py:291 [00:33:42])
# [DEBUG]: https://huggingface.co:443 "HEAD /roberta-base/resolve/main/config.json HTTP/11" 200 0        (connectionpool.py:546 [00:33:42])
# [DEBUG]: https://huggingface.co:443 "HEAD /roberta-base/resolve/main/config.json HTTP/11" 200 0        (connectionpool.py:546 [00:33:42])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 19
#      16 latent_dim = 128  # Dimension of sampled latent variable
#      17 hidden_dim = 128  # Dimension of hidden layers in encoder and decoder
# ---> 19 model = InformedNeuralProcess(
#      20     x_dim=x_dim,
#      21     y_dim=y_dim,
#      22     hidden_dim=hidden_dim,
#      23     latent_dim=latent_dim,
#      24     determ_dim=determ_dim,
#      25     knowledge_dim=128,
#      26     mlps_activation=nn.GELU(),
#      27     x_proj_dim=1,
#      28     n_h_layers_x_proj=0,
#      29     n_h_layers_decoder=4,
#      30     n_h_layers_latent_xy_encoder=3,
#      31     n_h_layers_film_latent_encoder=3,
#      32     path='latent',
#      33     train_num_z_samples=4,
#      34     test_num_z_samples=32,
#      35     use_bias=True,
#      36     user_context_in_target=True, # TODO investigate
#      37     use_latent_self_attn=True,
#      38     # use_determ_self_attn=True,
#      39     # use_determ_cross_attn=True,
#      40     use_knowledge=USE_KNOWLEDGE,
#      41     knowledge_dropout=0.3,
#      42     roberta_return_cls=True,
#      43     tune_llm_layer_norms=True,
#      44     freeze_llm=True,
#      45     knowledge_projection_n_h_layers=0,
#      46     knowledge_aggregation_method='FiLM+MLP',
#      47     device='cuda',
#      48     beta=1.0
#      49 ).to(DEVICE)
#      51 logging.info(model)
#      52 logging.info(f'Number of model parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}')
#
# File /home/w/IML/notebooks/../src/informed_np.py:120, in InformedNeuralProcess.__init__(self, x_dim, y_dim, hidden_dim, latent_dim, determ_dim, knowledge_dim, mlps_activation, x_proj_dim, n_h_layers_x_proj, n_h_layers_decoder, n_h_layers_latent_xy_encoder, n_h_layers_film_latent_encoder, n_h_layers_phi_determ_encoder, n_h_layers_rho_determ_encoder, path, train_num_z_samples, test_num_z_samples, use_bias, user_context_in_target, use_latent_self_attn, use_determ_self_attn, use_determ_cross_attn, use_knowledge, knowledge_dropout, roberta_return_cls, tune_llm_layer_norms, freeze_llm, knowledge_projection_n_h_layers, knowledge_aggregation_method, device, beta)
#     111     # else:
#     112     #     self.latent_encoder = RhoLatentEncoder(
#     113     #                             hidden_dim=hidden_dim,
#    (...)
#     116     #                             use_bias=use_bias,
#     117     #                             activation=mlps_activation)
#     119 if use_knowledge:
# --> 120     self.knowledge_encoder = RoBERTaKnowledgeEncoder(
#     121         knowledge_dim=knowledge_dim,
#     122         return_cls=roberta_return_cls,
#     123         tune_llm_layer_norms=tune_llm_layer_norms,
#     124         freeze_llm=freeze_llm,
#     125         knowledge_projection_n_h_layers=knowledge_projection_n_h_layers,
#     126         knowledge_projection_hidden_dim=hidden_dim,
#     127         knowledge_projection_activation=mlps_activation,
#     128         use_bias=use_bias,
#     129         device=device,
#     130     )
#     133 if path in ['deterministic', 'both']:
#     134     self.deterministic_encoder = DeterminisitcEncoder(
#     135             x_dim=x_dim,
#     136             y_dim=y_dim,
#    (...)
#     143             use_bias = use_bias
#     144     )
#
# File /home/w/IML/notebooks/../src/modules/knowledge_encoder.py:108, in RoBERTaKnowledgeEncoder.__init__(self, knowledge_dim, return_cls, freeze_llm, tune_llm_layer_norms, use_bias, device, knowledge_projection_n_h_layers, knowledge_projection_hidden_dim, knowledge_projection_activation)
#      92 """
#      93 Parameters
#      94 ----------
#    (...)
#     104     Number of hidden layers in the projection MLP
#     105 """
#     106 super().__init__()
# --> 108 self.text_encoder = RoBERTa(
#     109     return_cls=return_cls,
#     110     device=device,
#     111     tune_llm_layer_norms=tune_llm_layer_norms,
#     112     freeze_llm=freeze_llm
#     113 )
#     115 self.projection = MLP(
#     116     input_dim=self.text_encoder.dim_model,
#     117     output_dim=knowledge_dim,
#    (...)
#     121     hidden_activation=knowledge_projection_activation
#     122 )
#
# File /home/w/IML/notebooks/../src/modules/knowledge_encoder.py:22, in RoBERTa.__init__(self, return_cls, device, tune_llm_layer_norms, freeze_llm)
#      19 super().__init__()
#      21 self.dim_model = 768
# ---> 22 self.llm = RobertaModel.from_pretrained("roberta-base")
#      24 self.return_cls = return_cls
#      25 self.device =device
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:3838, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3828     if dtype_orig is not None:
#    3829         torch.set_default_dtype(dtype_orig)
#    3831     (
#    3832         model,
#    3833         missing_keys,
#    3834         unexpected_keys,
#    3835         mismatched_keys,
#    3836         offload_index,
#    3837         error_msgs,
# -> 3838     ) = cls._load_pretrained_model(
#    3839         model,
#    3840         state_dict,
#    3841         loaded_state_dict_keys,  # XXX: rename?
#    3842         resolved_archive_file,
#    3843         pretrained_model_name_or_path,
#    3844         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3845         sharded_metadata=sharded_metadata,
#    3846         _fast_init=_fast_init,
#    3847         low_cpu_mem_usage=low_cpu_mem_usage,
#    3848         device_map=device_map,
#    3849         offload_folder=offload_folder,
#    3850         offload_state_dict=offload_state_dict,
#    3851         dtype=torch_dtype,
#    3852         hf_quantizer=hf_quantizer,
#    3853         keep_in_fp32_modules=keep_in_fp32_modules,
#    3854         gguf_path=gguf_path,
#    3855     )
#    3857 # make sure token embedding weights are still tied if needed
#    3858 model.tie_weights()
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:4246, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path)
#    4227         error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4228             model_to_load,
#    4229             state_dict,
#    (...)
#    4242             unexpected_keys=unexpected_keys,
#    4243         )
#    4244     else:
#    4245         # Sharded checkpoint or whole but low_cpu_mem_usage==True
# -> 4246         error_msgs = _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#    4248 else:
#    4249     # This should always be a list but, just to be sure.
#    4250     if not isinstance(resolved_archive_file, list):
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:711, in _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#     708         if child is not None:
#     709             load(child, state_dict, prefix + name + ".")
# --> 711 load(model_to_load, state_dict, prefix=start_prefix)
#     712 # Delete `state_dict` so it could be collected by GC earlier. Note that `state_dict` is a copy of the argument, so
#     713 # it's safe to delete it.
#     714 del state_dict
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:709, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     707 for name, child in module._modules.items():
#     708     if child is not None:
# --> 709         load(child, state_dict, prefix + name + ".")
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:709, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     707 for name, child in module._modules.items():
#     708     if child is not None:
# --> 709         load(child, state_dict, prefix + name + ".")
#
#     [... skipping similar frames: _load_state_dict_into_model.<locals>.load at line 709 (2 times)]
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:709, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     707 for name, child in module._modules.items():
#     708     if child is not None:
# --> 709         load(child, state_dict, prefix + name + ".")
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:705, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     703                     module._load_from_state_dict(*args)
#     704     else:
# --> 705         module._load_from_state_dict(*args)
#     707 for name, child in module._modules.items():
#     708     if child is not None:
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:2075, in Module._load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    2073             setattr(self, name, input_param)
#    2074         else:
# -> 2075             param.copy_(input_param)
#    2076 except Exception as ex:
#    2077     action = "swapping" if use_swap_tensors else "copying"
#
# KeyboardInterrupt:

# %%
# plt.plot(train_loss, label='train_loss')
# window = 50
# plt.plot([sum(train_loss[i:i+window])/window for i in range(len(train_loss)-window)], label=f'train_loss_{window}_smooth')
# plt.legend()
# plt.show()
# Out:
#   0%|          | 0/4500 [00:00<?, ?it/s]
# iter 1: Val. Loss: 518.0661125183105
#   6%|▌         | 249/4500 [00:36<05:30, 12.85it/s]
# iter 250: avg. Train Loss = 482.946931640625
#   6%|▌         | 251/4500 [00:52<2:46:53,  2.36s/it]
# iter 250: Val. Loss: 521.512971162796
#  11%|█         | 498/4500 [01:12<05:17, 12.60it/s]
# iter 500: avg. Train Loss = 437.60939379882814
#  11%|█         | 499/4500 [01:20<10:46,  6.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 11
#       8 data = pd.read_csv(data_path, header=None)
#       9 data = TempData(data=data , max_num_context=10, device=DEVICE)
# ---> 11 model, optimiser, train_losses, val_losses = train(model=model,
#      12                                                    data=data,
#      13                                                    loss_function=loss_function,
#      14                                                    optimiser=optimiser,
#      15                                                    device=DEVICE,
#      16                                                    use_knowledge=USE_KNOWLEDGE,
#      17                                                    max_iters=MAX_ITERS,
#      18                                                    avg_loss_print_interval=AVG_LOSS_PRINT_INTERVAL,
#      19                                                    plot_sample_interval=PLOT_SAMPLE_INTERVAL)
#      21 # plt.plot(train_loss, label='train_loss')
#      22 # window = 50
#      23 # plt.plot([sum(train_loss[i:i+window])/window for i in range(len(train_loss)-window)], label=f'train_loss_{window}_smooth')
#      24 # plt.legend()
#      25 # plt.show()
#
# File /home/w/IML/notebooks/../src/train.py:89, in train(model, data, loss_function, optimiser, device, use_knowledge, max_iters, avg_loss_print_interval, plot_sample_interval, model_save_name)
#      84 batch = data.generate_batch(batch_size=val_batch_size,
#      85                             device=device,
#      86                             return_knowledge=use_knowledge,
#      87                             split='val')
#      88 model.training = False
# ---> 89 p_y_pred, q_z_context, q_z_target = model(batch.x_context,
#      90                                           batch.y_context,
#      91                                           batch.x_target,
#      92                                           batch.y_target,
#      93                                           batch.knowledge)
#      94 val_loss_dict = loss_function(p_y_pred, q_z_context, None, batch.y_target)
#      95 val_loss += val_loss_dict["loss"].item() / n_val_batches
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /home/w/IML/notebooks/../src/informed_np.py:178, in InformedNeuralProcess.forward(self, x_context, y_context, x_target, y_target, textual_knowledge)
#     176 # Encode context set
#     177 r_context = self.xy_encoder_latent(x_context, y_context) # Shape (batch_size, 1, hidden_dim)
# --> 178 q_z_context = self.latent_encoder(r_context, k)
#     181 if self.training:
#     182     assert y_target is not None, "y_target must be provided during training"
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /home/w/IML/notebooks/../src/modules/latent_encoder.py:100, in FiLMLatentEncoder.forward(self, r, k)
#      97 mean, pre_stddev = torch.chunk(latent_output, 2, dim=-1)
#      98 stddev = 0.1 + 0.9*F.sigmoid(pre_stddev) # Shape (batch_size, 1, latent_dim)
# --> 100 return MultivariateNormalDiag(mean, stddev)
#
# File /home/w/IML/notebooks/../src/modules/multivariate_diag.py:12, in MultivariateNormalDiag(loc, scale_diag)
#      10 if loc.dim() < 1:
#      11     raise ValueError("loc must be at least one-dimensional.")
# ---> 12 return Independent(Normal(loc, scale_diag), 1)
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/distributions/normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/distributions/distribution.py:67, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      65         value = getattr(self, param)
#      66         valid = constraint.check(value)
# ---> 67         if not valid.all():
#      68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# KeyboardInterrupt:

# %%
USE_KNOWLEDGE = False

nok_model = InformedNeuralProcess(
    x_dim=x_dim,
    y_dim=y_dim,
    hidden_dim=hidden_dim,
    latent_dim=latent_dim,
    determ_dim=determ_dim,
    knowledge_dim=128,
    mlps_activation=nn.GELU(),
    x_proj_dim=1,
    n_h_layers_x_proj=0,
    n_h_layers_decoder=4,
    n_h_layers_latent_xy_encoder=3,
    n_h_layers_film_latent_encoder=3,
    path='latent',
    train_num_z_samples=4,
    test_num_z_samples=32,
    use_bias=True,
    user_context_in_target=True, # TODO investigate
    use_latent_self_attn=True,
    # use_determ_self_attn=True,
    # use_determ_cross_attn=True,
    use_knowledge=USE_KNOWLEDGE,
    knowledge_dropout=0.3,
    roberta_return_cls=True,
    tune_llm_layer_norms=True,
    freeze_llm=True,
    knowledge_projection_n_h_layers=0,
    knowledge_aggregation_method='FiLM+MLP',
    device='cuda',
    beta=1.0
).to(DEVICE)

logging.info(nok_model)
logging.info(f'Number of model parameters: {sum(p.numel() for p in nok_model.parameters() if p.requires_grad)}')


nok_model, optimiser, train_losses, val_losses = train(model=nok_model,
                                                   data=data,
                                                   loss_function=loss_function,
                                                   optimiser=optimiser,
                                                   device=DEVICE,
                                                   use_knowledge=USE_KNOWLEDGE,
                                                   max_iters=MAX_ITERS,
                                                   avg_loss_print_interval=AVG_LOSS_PRINT_INTERVAL,
                                                   plot_sample_interval=PLOT_SAMPLE_INTERVAL,
                                                   model_save_name="NoK")
# Out:
# [WARNING]: Hidden activation set but no hidden layers        (mlp.py:22 [22:27:40])
# [WARNING]: Hidden activation set but no hidden layers        (mlp.py:22 [22:27:40])
# [DEBUG]: XYEncoder has x_dim=1 and y_dim=1        (xy_encoders.py:57 [22:27:40])
# [INFO]: InformedNeuralProcess(
#   (x_context_encoder): XEncoder(
#     (mlp): MLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=1, out_features=1, bias=True)
#       )
#     )
#   )
#   (x_target_encoder): XEncoder(
#     (mlp): MLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=1, out_features=128, bias=True)
#       )
#     )
#   )
#   (xy_encoder_latent): XYSetEncoder(
#     (phi): MLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=2, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): GELU(approximate='none')
#         (4): Linear(in_features=128, out_features=128, bias=True)
#         (5): GELU(approximate='none')
#         (6): Linear(in_features=128, out_features=128, bias=True)
#       )
#     )
#     (self_attention_block): MultiheadAttention(
#       (qkv_proj): Linear(in_features=128, out_features=384, bias=True)
#       (o_proj): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (latent_encoder): FiLMLatentEncoder(
#     (FiLM_blocks): ModuleList(
#       (0-2): 3 x LinearFiLMActBlock(
#         (linear): Linear(in_features=128, out_features=128, bias=True)
#         (activation): GELU(approximate='none')
#       )
#     )
#     (output_layer): Linear(in_features=128, out_features=256, bias=True)
#   )
#   (decoder): Decoder(
#     (decoder): MLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=256, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): GELU(approximate='none')
#         (4): Linear(in_features=128, out_features=128, bias=True)
#         (5): GELU(approximate='none')
#         (6): Linear(in_features=128, out_features=128, bias=True)
#         (7): GELU(approximate='none')
#         (8): Linear(in_features=128, out_features=2, bias=True)
#       )
#     )
#   )
# )        (317647201.py:35 [22:27:40])
# [INFO]: Number of model parameters: 281476        (317647201.py:36 [22:27:40])
# [INFO]: Using optimiser Adam        (317647201.py:39 [22:27:40])
#   0%|          | 0/10000 [00:00<?, ?it/s]
# iter 1: Val. Loss: 15389.782279968262
#   2%|▏         | 244/10000 [00:05<02:35, 62.58it/s]
# iter 250: avg. Train Loss = 1742.5689306640625
# [INFO]: Saving new best val loss model at iter 250        (train.py:105 [22:27:47])
#   3%|▎         | 258/10000 [00:07<09:38, 16.83it/s]
# iter 250: Val. Loss: 666.5004806518555
#   5%|▍         | 497/10000 [00:10<02:33, 61.82it/s]
# iter 500: avg. Train Loss = 568.9498115234375
# [INFO]: Saving new best val loss model at iter 500        (train.py:105 [22:27:52])
#   5%|▌         | 511/10000 [00:12<09:32, 16.57it/s]
# iter 500: Val. Loss: 611.6853890419006
#   7%|▋         | 749/10000 [00:16<02:30, 61.67it/s]
# iter 750: avg. Train Loss = 490.80680737304687
#   8%|▊         | 756/10000 [00:17<12:11, 12.64it/s]
# iter 750: Val. Loss: 657.8899216651917
#  10%|▉         | 994/10000 [00:21<02:23, 62.79it/s]
# iter 1000: avg. Train Loss = 467.25531311035155
# iter 1000: Val. Loss: 650.5511441230774
#  12%|█▏        | 1245/10000 [00:27<01:58, 74.10it/s]
# iter 1250: avg. Train Loss = 454.60608825683596
#  13%|█▎        | 1260/10000 [00:28<07:45, 18.77it/s]
# iter 1250: Val. Loss: 675.1802892684937
#  85%|████████▌ | 8508/10000 [03:03<01:24, 17.60it/s]
# iter 8500: Val. Loss: 1985.339210510254
#  87%|████████▋ | 8746/10000 [03:07<00:20, 61.83it/s]
# iter 8750: avg. Train Loss = 191.07451611328125
#  88%|████████▊ | 8760/10000 [03:09<01:14, 16.67it/s]
# iter 8750: Val. Loss: 2476.0114393234253
#  90%|████████▉ | 8997/10000 [03:12<00:14, 67.75it/s]
# iter 9000: avg. Train Loss = 179.77424362182617
# iter 9000: Val. Loss: 2258.1373357772827
#  92%|█████████▏| 9248/10000 [03:17<00:11, 62.76it/s]
# iter 9250: avg. Train Loss = 183.44169998168945
#  93%|█████████▎| 9262/10000 [03:19<00:43, 16.85it/s]
# iter 9250: Val. Loss: 3153.9391298294067
#  95%|█████████▍| 9496/10000 [03:23<00:06, 77.74it/s]
# iter 9500: avg. Train Loss = 174.61204107666015
#  95%|█████████▌| 9511/10000 [03:24<00:26, 18.52it/s]
# iter 9500: Val. Loss: 2803.5753536224365
#  97%|█████████▋| 9746/10000 [03:28<00:04, 62.59it/s]
# iter 9750: avg. Train Loss = 159.04975463867189
#  98%|█████████▊| 9760/10000 [03:29<00:14, 16.75it/s]
# iter 9750: Val. Loss: 3183.033574104309
# 100%|█████████▉| 9993/10000 [03:33<00:00, 62.68it/s]
# iter 10000: avg. Train Loss = 156.16000021362305
# iter 10000: Val. Loss: 2819.818078994751
# 100%|██████████| 10000/10000 [03:35<00:00, 46.46it/s]

# %%
model.load_state_dict(torch.load("../exp/bestK_iter3750.pt"))
nok_model.load_state_dict(torch.load("../exp/bestNoK_iter500.pt"))

batch = data.generate_batch(batch_size=1,
                            device=DEVICE,
                            split='test',
                            return_knowledge=True,
                           num_context=3)
plot_predictive(model, batch)
plot_predictive(nok_model, batch)
# print(batch.knowledge)
# no = 3
# plot_predictive(model, batch, save=True, save_name=f"../figures/INP_trained_sample{no}")
# plot_predictive(no_knowledge_model, batch, save=True, save_name=f"../figures/NP_trained_sample{no}")

# %%
model.training = False
batch = data.generate_batch(batch_size=1, training=False, device=model.device)
plot_predictive(model, batch, knowledge=None, save=False, iter=None)
model.training = True

# %%
import transformers
from transformers import RobertaModel, RobertaTokenizer
tokenizer = RobertaTokenizer.from_pretrained('roberta-base', truncation=True, do_lower_case=True)
langmodel = RobertaModel.from_pretrained("roberta-base")
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
langmodel.to(device)
# freeze everything
for name, param in langmodel.named_parameters():
    if "LayerNorm" in name or name == 'pooler.dense.bias' or name == 'pooler.dense.weight':
        param.requires_grad = True
    else:
        param.requires_grad = False

#verify
for name, param in langmodel.named_parameters():
    print(name,param.requires_grad)
# Out:
# [DEBUG]: Starting new HTTPS connection (1): huggingface.co:443  ([2024-07-19 08:54:44] connectionpool.py:1051)
# [DEBUG]: https://huggingface.co:443 "HEAD /roberta-base/resolve/main/tokenizer_config.json HTTP/11" 200 0  ([2024-07-19 08:54:44] connectionpool.py:546)
# [DEBUG]: https://huggingface.co:443 "HEAD /roberta-base/resolve/main/config.json HTTP/11" 200 0  ([2024-07-19 08:54:44] connectionpool.py:546)
# [DEBUG]: https://huggingface.co:443 "HEAD /roberta-base/resolve/main/config.json HTTP/11" 200 0  ([2024-07-19 08:54:44] connectionpool.py:546)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 4
#       2 from transformers import RobertaModel, RobertaTokenizer
#       3 tokenizer = RobertaTokenizer.from_pretrained('roberta-base', truncation=True, do_lower_case=True)
# ----> 4 langmodel = RobertaModel.from_pretrained("roberta-base")
#       5 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#       6 langmodel.to(device)
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:3838, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3828     if dtype_orig is not None:
#    3829         torch.set_default_dtype(dtype_orig)
#    3831     (
#    3832         model,
#    3833         missing_keys,
#    3834         unexpected_keys,
#    3835         mismatched_keys,
#    3836         offload_index,
#    3837         error_msgs,
# -> 3838     ) = cls._load_pretrained_model(
#    3839         model,
#    3840         state_dict,
#    3841         loaded_state_dict_keys,  # XXX: rename?
#    3842         resolved_archive_file,
#    3843         pretrained_model_name_or_path,
#    3844         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3845         sharded_metadata=sharded_metadata,
#    3846         _fast_init=_fast_init,
#    3847         low_cpu_mem_usage=low_cpu_mem_usage,
#    3848         device_map=device_map,
#    3849         offload_folder=offload_folder,
#    3850         offload_state_dict=offload_state_dict,
#    3851         dtype=torch_dtype,
#    3852         hf_quantizer=hf_quantizer,
#    3853         keep_in_fp32_modules=keep_in_fp32_modules,
#    3854         gguf_path=gguf_path,
#    3855     )
#    3857 # make sure token embedding weights are still tied if needed
#    3858 model.tie_weights()
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:4246, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path)
#    4227         error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4228             model_to_load,
#    4229             state_dict,
#    (...)
#    4242             unexpected_keys=unexpected_keys,
#    4243         )
#    4244     else:
#    4245         # Sharded checkpoint or whole but low_cpu_mem_usage==True
# -> 4246         error_msgs = _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#    4248 else:
#    4249     # This should always be a list but, just to be sure.
#    4250     if not isinstance(resolved_archive_file, list):
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:711, in _load_state_dict_into_model(model_to_load, state_dict, start_prefix)
#     708         if child is not None:
#     709             load(child, state_dict, prefix + name + ".")
# --> 711 load(model_to_load, state_dict, prefix=start_prefix)
#     712 # Delete `state_dict` so it could be collected by GC earlier. Note that `state_dict` is a copy of the argument, so
#     713 # it's safe to delete it.
#     714 del state_dict
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:709, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     707 for name, child in module._modules.items():
#     708     if child is not None:
# --> 709         load(child, state_dict, prefix + name + ".")
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:709, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     707 for name, child in module._modules.items():
#     708     if child is not None:
# --> 709         load(child, state_dict, prefix + name + ".")
#
#     [... skipping similar frames: _load_state_dict_into_model.<locals>.load at line 709 (3 times)]
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:709, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     707 for name, child in module._modules.items():
#     708     if child is not None:
# --> 709         load(child, state_dict, prefix + name + ".")
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/transformers/modeling_utils.py:705, in _load_state_dict_into_model.<locals>.load(module, state_dict, prefix)
#     703                     module._load_from_state_dict(*args)
#     704     else:
# --> 705         module._load_from_state_dict(*args)
#     707 for name, child in module._modules.items():
#     708     if child is not None:
#
# File /home/w/IML/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:2075, in Module._load_from_state_dict(self, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs)
#    2073             setattr(self, name, input_param)
#    2074         else:
# -> 2075             param.copy_(input_param)
#    2076 except Exception as ex:
#    2077     action = "swapping" if use_swap_tensors else "copying"
#
# KeyboardInterrupt:

# %%
from src.plot import plot_predictive
from src.np import NeuralProcess

x_dim = 1
y_dim = 1
determ_dim = 128  # Dimension of representation of context points
latent_dim = 128  # Dimension of sampled latent variable
hidden_dim = 128  # Dimension of hidden layers in encoder and decoder

# np = NeuralProcess(x_dim=x_dim,
#                    y_dim=y_dim,
#                    hidden_dim=hidden_dim,
#                    latent_dim=latent_dim,
#                    determ_dim=determ_dim,
#                    knowledge_dim=768,
#                    n_h_layers_decoder=3,
#                    n_h_layers_phi_latent_encoder=2,
#                    n_h_layers_rho_latent_encoder=1,
#                    n_h_layers_phi_determ_encoder=6,
#                    n_h_layers_rho_determ_encoder=0,
#                    use_deterministic_path=False,
#                    )

model = NeuralProcess(x_dim=x_dim,
                   y_dim=y_dim,
                   hidden_dim=hidden_dim,
                   latent_dim=latent_dim,
                   determ_dim=determ_dim,
                   n_h_layers_decoder=4,
                   n_h_layers_phi_latent_encoder=2,
                   n_h_layers_rho_latent_encoder=1,
                   n_h_layers_phi_determ_encoder=5,
                   n_h_layers_rho_determ_encoder=0,
                   use_deterministic_path=True,
                   use_latent_self_attn=True,
                   use_determ_self_attn=False,
                   use_determ_cross_attn=True,
                   use_knowledge=True,
                   use_linear_knowledge_encoder=True,
                   knowledge_aggregation_method='FiLM+MLP',
                   knowledge_dim=768
                   )
print(model)
print(sum(p.numel() for p in model.parameters() if p.requires_grad))

#data = SineData(max_num_context=30, random_kernel_parameters=True)
optimiser = torch.optim.Adam(model.parameters(), lr=5e-4)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device {device}")
model.to(device)

def preprocess_knowledge(knowledge_pre, langmodel, tokenizer):
    tokens = tokenizer.batch_encode_plus(
                        list(knowledge_pre),
                        add_special_tokens=True,
                        max_length=110,
                        padding='max_length',
                        return_token_type_ids=True
                    )
    input_ids = torch.tensor(tokens['input_ids']).to(device)
    attention_mask = torch.tensor(tokens['attention_mask']).to(device)
    token_type_ids = torch.tensor(tokens['token_type_ids']).to(device)
    lang_output = langmodel(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
    knowledge_post = lang_output.pooler_output.unsqueeze(1)
    return knowledge_post

data_path = '../data/data_with_desc.csv'
data = pd.read_csv(data_path, header=None)
data = TempData(data=data , max_num_context=10, device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu"))
train_loss = []
avg_loss_fast = 0
avg_loss_slow = 0
for iter in tqdm(range(100000+1), mininterval=10):
    model.training = True
    optimiser.zero_grad()

    batch, knowledge_pre = data.generate_batch(batch_size=64, device=device, return_knowledge=True)
    # print(knowledge)
    knowledge = preprocess_knowledge(knowledge_pre, langmodel, tokenizer)

    zero_prob = 0.3
    mask = torch.rand((64, 1, 1), device=device) > 0.3
    knowledge = knowledge * mask
    # print(knowledge)
    # break
    
    p_y_pred, loss, log_lik = model(batch.x_context, batch.y_context, batch.x_target, knowledge, batch.y_target)
    # print(loss.item())
    loss.backward()
    optimiser.step()
    train_loss.append(loss.item())

    avg_loss_slow += loss.item()
    avg_loss_fast += loss.item()

    if iter % 1000 == 0 and iter > 0:
        print(f"iter {iter+1}: Avg. Loss = {avg_loss_fast/1000}")
        #print(f"iter. loss = {loss.item()}, iter. Loss2 (not being backpropped on) = {loss2.item()}")
        avg_loss_fast = 0
    if iter % 10000 == 0:
        print(f"iter {iter+1}: Avg. Loss SLOW = {avg_loss_slow/1000}")
        avg_loss_slow = 0
        
        with torch.no_grad():
            val_loss = 0
            n_val_batches = 32
            val_batch_size = 64
            for _ in range(n_val_batches):
                batch, knowledge_pre = data.generate_batch(batch_size=val_batch_size, training=False, device=model.device, return_knowledge=True)
                knowledge = preprocess_knowledge(knowledge_pre, langmodel, tokenizer)
                
                p_y_pred, _loss, log_lik = model(batch.x_context, batch.y_context, batch.x_target, knowledge, batch.y_target)
                val_loss += _loss
            print(f"Val Loss: {val_loss / n_val_batches}")
        
    # if iter % 20000 == 0:
        model.training = False
        batch, knowledge_pre = data.generate_batch(batch_size=1, device=model.device, training=False, return_knowledge=True)
        knowledge = preprocess_knowledge(knowledge_pre, langmodel, tokenizer)
        plot_predictive(model, batch, knowledge=knowledge, save=False, iter=None)
        model.training = True

plt.plot(train_loss, label='train_loss')
window = 50
plt.plot([sum(train_loss[i:i+window])/window for i in range(len(train_loss)-window)], label=f'train_loss_{window}_smooth')
plt.legend()
plt.show()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# NeuralProcess(
#   (deterministic_encoder): DeterminisitcEncoder(
#     (phi): BatchMLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=2, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): GELU(approximate='none')
#         (4): Linear(in_features=128, out_features=128, bias=True)
#         (5): GELU(approximate='none')
#         (6): Linear(in_features=128, out_features=128, bias=True)
#         (7): GELU(approximate='none')
#         (8): Linear(in_features=128, out_features=128, bias=True)
#         (9): GELU(approximate='none')
#         (10): Linear(in_features=128, out_features=128, bias=True)
#         (11): Identity()
#       )
#     )
#     (rho): Linear(in_features=128, out_features=128, bias=True)
#     (cross_attention_block): CrossAttention(
#       (q_proj): Linear(in_features=128, out_features=128, bias=True)
#       (k_proj): Linear(in_features=128, out_features=128, bias=True)
#       (v_proj): Linear(in_features=128, out_features=128, bias=True)
#       (o_proj): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (x_to_querykey): BatchMLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=1, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): GELU(approximate='none')
#         (4): Linear(in_features=128, out_features=128, bias=True)
#         (5): Identity()
#       )
#     )
#   )
#   (knowledge_encoder): KnowledgeEncoder(
#     (linear): Linear(in_features=768, out_features=128, bias=True)
#   )
#   (latent_encoder): LatentEncoder(
#     (phi): BatchMLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=2, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): GELU(approximate='none')
#         (4): Linear(in_features=128, out_features=128, bias=True)
#         (5): Identity()
#       )
#     )
#     (rho): FiLM_MLP(
#       (FiLM_generator): Linear(in_features=128, out_features=256, bias=True)
#       (FiLM_mlp): ModuleList(
#         (0): Linear(in_features=128, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): FiLMBlock()
#         (3): Linear(in_features=128, out_features=256, bias=True)
#         (4): Identity()
#       )
#     )
#     (self_attention_block): MultiheadAttention(
#       (qkv_proj): Linear(in_features=128, out_features=384, bias=True)
#       (o_proj): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (target_transform): Linear(in_features=1, out_features=128, bias=True)
#     (decoder): BatchMLP(
#       (mlp): Sequential(
#         (0): Linear(in_features=384, out_features=128, bias=True)
#         (1): GELU(approximate='none')
#         (2): Linear(in_features=128, out_features=128, bias=True)
#         (3): GELU(approximate='none')
#         (4): Linear(in_features=128, out_features=128, bias=True)
#         (5): GELU(approximate='none')
#         (6): Linear(in_features=128, out_features=128, bias=True)
#         (7): GELU(approximate='none')
#         (8): Linear(in_features=128, out_features=2, bias=True)
#         (9): Identity()
#       )
#     )
#   )
# )
# 578562
# Using device cuda:0
#   0%|          | 0/100001 [00:00<?, ?it/s]
# iter 1: Avg. Loss SLOW = 23.9564296875
# Val Loss: 16363.0146484375
#   1%|          | 984/100001 [02:21<3:51:53,  7.12it/s]
# iter 1001: Avg. Loss = 1371.3650053710937
#   2%|▏         | 1979/100001 [04:42<3:49:56,  7.10it/s]
# iter 2001: Avg. Loss = 825.6592733154297
#   3%|▎         | 2987/100001 [07:03<3:45:45,  7.16it/s]
# iter 3001: Avg. Loss = 609.216155670166
#   4%|▍         | 3995/100001 [09:24<3:43:55,  7.15it/s]
# iter 4001: Avg. Loss = 572.6883545837402
#   5%|▌         | 5002/100001 [11:45<3:42:38,  7.11it/s]
# iter 5001: Avg. Loss = 559.4265250244141
#   6%|▌         | 5938/100001 [13:57<3:40:23,  7.11it/s]
# iter 6001: Avg. Loss = 548.3296486206054
#   7%|▋         | 6948/100001 [16:18<3:37:01,  7.15it/s]
# iter 7001: Avg. Loss = 549.4437937316894
#   8%|▊         | 7956/100001 [18:40<3:34:40,  7.15it/s]
# iter 8001: Avg. Loss = 547.3991734008789
#   9%|▉         | 8964/100001 [21:01<3:33:03,  7.12it/s]
# iter 9001: Avg. Loss = 538.3132267150879
#  10%|▉         | 9972/100001 [23:22<3:29:51,  7.15it/s]
# iter 10001: Avg. Loss = 542.1308537597656
# iter 10001: Avg. Loss SLOW = 6640.015580505371
# Val Loss: 539.7378540039062
#  11%|█         | 10979/100001 [25:46<3:29:05,  7.10it/s]
# iter 11001: Avg. Loss = 543.0914686279297
#  12%|█▏        | 11988/100001 [28:08<3:24:44,  7.16it/s]
# iter 12001: Avg. Loss = 532.3450851135254
#  13%|█▎        | 12999/100001 [30:29<3:23:06,  7.14it/s]
# iter 85001: Avg. Loss = 463.2252283935547
#  86%|████████▌ | 86000/100001 [3:19:54<32:31,  7.18it/s]
# iter 86001: Avg. Loss = 459.400683013916
#  87%|████████▋ | 86947/100001 [3:22:05<30:05,  7.23it/s]
# iter 87001: Avg. Loss = 458.2623641052246
#  88%|████████▊ | 87968/100001 [3:24:27<27:50,  7.20it/s]
# iter 88001: Avg. Loss = 458.81936056518555
#  89%|████████▉ | 88990/100001 [3:26:49<25:25,  7.22it/s]
# iter 89001: Avg. Loss = 454.3959769592285
#  90%|████████▉ | 89939/100001 [3:29:00<23:13,  7.22it/s]
# iter 90001: Avg. Loss = 459.143133605957
# iter 90001: Avg. Loss SLOW = 4613.039724975586
# Val Loss: 576.7901000976562
#  91%|█████████ | 90956/100001 [3:31:24<20:56,  7.20it/s]
# iter 91001: Avg. Loss = 465.2961449584961
#  92%|█████████▏| 91971/100001 [3:33:45<18:33,  7.21it/s]
# iter 92001: Avg. Loss = 461.93221728515624
#  93%|█████████▎| 92991/100001 [3:36:06<16:13,  7.20it/s]
# iter 93001: Avg. Loss = 458.30853015136717
#  94%|█████████▍| 93931/100001 [3:38:17<14:06,  7.17it/s]
# iter 94001: Avg. Loss = 460.73588708496095
#  95%|█████████▍| 94944/100001 [3:40:38<11:43,  7.19it/s]
# iter 95001: Avg. Loss = 454.50996127319337
#  96%|█████████▌| 95959/100001 [3:43:00<09:23,  7.18it/s]
# iter 96001: Avg. Loss = 448.89369677734373
#  97%|█████████▋| 96979/100001 [3:45:21<06:59,  7.21it/s]
# iter 97001: Avg. Loss = 458.3916351623535
#  98%|█████████▊| 97993/100001 [3:47:42<04:39,  7.19it/s]
# iter 98001: Avg. Loss = 457.97456723022464
#  99%|█████████▉| 98934/100001 [3:49:53<02:28,  7.18it/s]
# iter 99001: Avg. Loss = 457.12769848632814
# 100%|█████████▉| 99956/100001 [3:52:15<00:06,  7.21it/s]
# iter 100001: Avg. Loss = 475.8789781188965
# iter 100001: Avg. Loss SLOW = 4599.049316528321
# Val Loss: 606.09228515625
# 100%|██████████| 100001/100001 [3:52:24<00:00,  7.17it/s]

# %%
# torch.save(np.state_dict(), f'../exp/{"inp_roberta_test1.pt"}')
model.load_state_dict(torch.load(f'../exp/{"inp_roberta_test1.pt"}'))
# Out:
# <All keys matched successfully>

# %%
model.training = False
batch, knowledge_pre = data.generate_batch(batch_size=1, device=model.device, return_knowledge=True)
print(knowledge_pre)
# Out:
# ['The night will start off cold with temperatures falling to -5.3°C by early morning, but it will gradually warm up reaching 6.2°C in the late afternoon, before cooling down again to -2.0°C at midnight.']

# %%
# knowledge_pre = ['The night will be bitterly cold with temperatures falling to -16.4°C, gradually rising to -13.4°C by early morning, and remarkably, the afternoon will see a significant temperature shift, hovering around freezing point at 0.3°C.']
knowledge_pre = ['The night will start off cold with temperatures falling to -5.3°C by early morning, but it will gradually warm up reaching 20°C in the late afternoon, before cooling down again to -2.0°C at midnight.']

model.training = False
knowledge = preprocess_knowledge(knowledge_pre, langmodel, tokenizer)
plot_predictive(model, batch, knowledge=knowledge, save=False, iter=None)

model.training = True
