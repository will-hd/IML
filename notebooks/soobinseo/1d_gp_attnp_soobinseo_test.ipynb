# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')

# %%
from data.gpdata_new import GPData
import matplotlib.pyplot as plt

sine_data_test = GPData(max_num_context=10)

batch = sine_data_test.generate_batch(batch_size=8, testing=True, device='cpu')

for i in range(8):
    x = batch.target_x[i].flatten()
    y = batch.target_y[i].flatten()
    plt.plot(x.numpy(), y.numpy())
plt.show()

# %%
import torch
import torch.nn as nn
from torch.distributions import Normal
from torch.distributions.kl import kl_divergence

def generate_knowledge(a, b, c):
    """
    a, b, c: torch.Tensor
        Shape (batch_size, 1, x_size)
    Knowledge can be none, a, b, c, ab, ac, bc 
    each vector is one-hot encoding of the parameter type with value appended to end
    e.g. if knowledge is a=1, b=0.5 then k = [1, 0, 0, 1], [0, 1, 0, 0.5]
    Returns 
    -------
    knowledge: torch.Tensor
        Shape (batch_size, num_knowledge_points, 4)
    """
    # sample types of knowledge to use as 3-vector. i.e. if ab then [1, 1, 0] if none then [0, 0, 0] etc
    binary_vector = torch.randint(0, 2, (3,))
    total_knowledge = []
    if binary_vector.sum() == 0:
        return None
    if binary_vector[0] == 1:
        # make [1, 0, 0, a]
        knowledge = torch.cat([torch.ones_like(a), torch.zeros_like(a), torch.zeros_like(a), a], dim=-1)
        total_knowledge.append(knowledge)
    if binary_vector[1] == 1:
        # make [0, 1, 0, b]
        knowledge = torch.cat([torch.zeros_like(b), torch.ones_like(b), torch.zeros_like(b), b], dim=-1)
        total_knowledge.append(knowledge)
    if binary_vector[2] == 1:
        # make [0, 0, 1, c]
        knowledge = torch.cat([torch.zeros_like(c), torch.zeros_like(c), torch.ones_like(c), c], dim=-1)
        total_knowledge.append(knowledge)
    total_knowledge = torch.cat(total_knowledge, dim=1)
    return total_knowledge



def loss_function(pred_dist: Normal, 
                  target_y: torch.Tensor,
                  posterior: Normal,
                  prior: Normal):

    batch_size, num_targets, _ = target_y.shape
    log_p = pred_dist.log_prob(target_y).sum(-1) # Shape (batch_size, num_targets)
    # assert log_p.shape[-1] == 1
    # log_p = log_p.squeeze(-1)

    kl_div = torch.sum(kl_divergence(posterior, prior), dim=-1, keepdim=True)

    loss = -torch.mean(log_p - kl_div / num_targets)
    return loss, log_p

def evaluate(model, data_generator, num_z_samples=32, num_test_batches=16, override_num_context=None, use_knowledge=False, batch_size=64):
    batch_losses = []
    device = model.device
    with torch.no_grad():
        model.training = False

        for _ in range(num_test_batches):
            batch_loss = 0
            batch = data_generator.generate_batch(batch_size=64, testing=True, override_num_context=override_num_context, device=device)
            if use_knowledge:
                knowledge = generate_knowledge(batch.a, batch.b, batch.c)
            else:
                knowledge = None
            for _ in range(num_z_samples):
                p_y_pred = model(batch.context_x, batch.context_y, knowledge, batch.target_x, batch.target_y)
                mu = p_y_pred.mean
                sigma = p_y_pred.stddev

                log_p = p_y_pred.log_prob(batch.target_y)
                log_p = log_p.mean(dim=0).mean() # Take mean over batch and mean over targets
                batch_loss += log_p
            batch_losses.append(batch_loss / num_z_samples)
    return torch.stack(batch_losses).mean().item()

# %%
from src.plot import plot_predictive
from data.sine_data import SineData
# from src.attnp import AttentiveNeuralProcess
from soobinseo.network import LatentModel
x_dim = 1
y_dim = 1
r_dim = 128  # Dimension of representation of context points
z_dim = 128  # Dimension of sampled latent variable
h_dim = 128  # Dimension of hidden layers in encoder and decoder
att_np = LatentModel(num_hidden=32)
print(att_np)
print(sum(p.numel() for p in att_np.parameters() if p.requires_grad))

#data = SineData(max_num_context=30, random_kernel_parameters=True)
data = GPData(max_num_context=30, random_kernel_parameters=True)
optimiser = torch.optim.Adam(att_np.parameters(), lr=1e-4)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device {device}")
att_np.to(device)

train_loss = []
for iter in range(100000+1):
    att_np.training = True
    optimiser.zero_grad()

    batch = data.generate_batch(batch_size=16, device=device)
    p_y_pred, q_z_target, q_z_context = att_np(batch.context_x, batch.context_y, batch.target_x, batch.target_y)

    loss, log_p = loss_function(p_y_pred, batch.target_y, q_z_target, q_z_context)

    loss.backward()
    optimiser.step()
    train_loss.append(loss.item())

    if iter % 200 == 0:
        print(f"Iter: {iter}, Loss {loss.item():.6f},") # NLL {nll:.6f}")
    if iter % 1000 == 0:
        att_np.training = False
        batch = data.generate_batch(1, testing=True, device=att_np.device)
        plot_predictive(att_np, batch, knowledge=None, save=False, iter=None)
        att_np.training = True

plt.plot(train_loss, label='train_loss')
window = 50
plt.plot([sum(train_loss[i:i+window])/window for i in range(len(train_loss)-window)], label=f'train_loss_{window}_smooth')
plt.legend()
plt.show()
# Out:
# LatentModel(
#   (latent_encoder): LatentEncoder(
#     (input_projection): Linear(
#       (linear_layer): Linear(in_features=2, out_features=128, bias=True)
#     )
#     (self_attentions): ModuleList(
#       (0-1): 2 x Attention(
#         (key): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (value): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (query): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (multihead): MultiheadAttention(
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (residual_dropout): Dropout(p=0.1, inplace=False)
#         (final_linear): Linear(
#           (linear_layer): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (penultimate_layer): Linear(
#       (linear_layer): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (mu): Linear(
#       (linear_layer): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (log_sigma): Linear(
#       (linear_layer): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (deterministic_encoder): DeterministicEncoder(
#     (self_attentions): ModuleList(
#       (0-1): 2 x Attention(
#         (key): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (value): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (query): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (multihead): MultiheadAttention(
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (residual_dropout): Dropout(p=0.1, inplace=False)
#         (final_linear): Linear(
#           (linear_layer): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (cross_attentions): ModuleList(
#       (0-1): 2 x Attention(
#         (key): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (value): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (query): Linear(
#           (linear_layer): Linear(in_features=128, out_features=128, bias=False)
#         )
#         (multihead): MultiheadAttention(
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (residual_dropout): Dropout(p=0.1, inplace=False)
#         (final_linear): Linear(
#           (linear_layer): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (layer_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (input_projection): Linear(
#       (linear_layer): Linear(in_features=2, out_features=128, bias=True)
#     )
#     (context_projection): Linear(
#       (linear_layer): Linear(in_features=1, out_features=128, bias=True)
#     )
#     (target_projection): Linear(
#       (linear_layer): Linear(in_features=1, out_features=128, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (target_projection): Linear(
#       (linear_layer): Linear(in_features=1, out_features=128, bias=True)
#     )
#     (linears): ModuleList(
#       (0-2): 3 x Linear(
#         (linear_layer): Linear(in_features=384, out_features=384, bias=True)
#       )
#     )
#     (final_projection): Linear(
#       (linear_layer): Linear(in_features=384, out_features=1, bias=True)
#     )
#   )
#   (BCELoss): BCELoss()
# )
# 988801
# Using device cuda:0
# torch.Size([16, 16, 4, 32])
# torch.Size([16, 16, 4, 32])
# torch.Size([16, 16, 4, 32])
# torch.Size([16, 16, 4, 32])
# torch.Size([16, 16, 4, 32])
# torch.Size([16, 16, 4, 32])
# torch.Size([16, 16, 4, 32])
# torch.Size([16, 16, 4, 32])
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [0,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [1,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [3,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [6,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [8,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [11,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [13,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [19,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [20,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [22,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [24,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [29,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [30,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [32,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [34,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [38,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [41,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [42,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [43,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [44,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [45,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [46,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [49,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [52,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [54,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [56,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [57,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [60,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [61,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [97,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [98,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [99,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [101,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [102,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [104,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [105,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [106,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [107,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [108,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [110,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [111,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [112,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [113,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [125,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [126,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [65,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [67,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [69,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [70,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [71,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [72,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [73,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [76,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [78,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [79,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [81,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [82,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [86,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [87,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [88,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [90,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [92,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [94,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# /opt/conda/conda-bld/pytorch_1699449201450/work/aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [95,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 27
#      24 optimiser.zero_grad()
#      26 batch = data.generate_batch(batch_size=16, device=device)
# ---> 27 p_y_pred, q_z_target, q_z_context = att_np(batch.context_x, batch.context_y, batch.target_x, batch.target_y)
#      29 loss, log_p = loss_function(p_y_pred, batch.target_y, q_z_target, q_z_context)
#      31 loss.backward()
#
# File ~/miniconda3/envs/pt2/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pt2/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/MLMI/project/notebooks/soobinseo/network.py:40, in LatentModel.forward(self, context_x, context_y, target_x, target_y)
#      37 bce_loss = self.BCELoss(t.sigmoid(y_pred), target_y)
#      39 # get KL divergence between prior and posterior
# ---> 40 kl = self.kl_div(prior_mu, prior_var, posterior_mu, posterior_var)
#      42 # maximize prob and minimize KL divergence
#      43 loss = bce_loss + kl
#
# File ~/MLMI/project/notebooks/soobinseo/network.py:54, in LatentModel.kl_div(self, prior_mu, prior_var, posterior_mu, posterior_var)
#      53 def kl_div(self, prior_mu, prior_var, posterior_mu, posterior_var):
# ---> 54     kl_div = (t.exp(posterior_var) + (posterior_mu-prior_mu) ** 2) / t.exp(prior_var) - 1. + (prior_var - posterior_var)
#      55     kl_div = 0.5 * kl_div.sum()
#      56     return kl_div
#
# File ~/miniconda3/envs/pt2/lib/python3.11/site-packages/torch/_tensor.py:40, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      38     if has_torch_function(args):
#      39         return handle_torch_function(wrapped, args, *args, **kwargs)
# ---> 40     return f(*args, **kwargs)
#      41 except TypeError:
#      42     return NotImplemented
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
x_dim = 1
y_dim = 1
r_dim = 64  # Dimension of representation of context points
z_dim = 64  # Dimension of sampled latent variable
h_dim = 64  # Dimension of hidden layers in encoder and decoder
att_np = AttentiveNeuralProcess(x_dim=x_dim,
                                y_dim=y_dim,
                                r_dim=r_dim,
                                z_dim=z_dim,
                                embed_dim=h_dim,
                                h_dim=h_dim,
                                ).to(device)
batch = data.generate_batch(1, testing=True, device=device)
for i in range(64):
    z_sample = torch.randn((1, z_dim))  # Shape (batch_size, z_dim)
    # Map x_target and z to p_y_target (which is parameterized by a 
    # normal with mean mu and std dev sigma)
    #py = anp.decoder(batch.x_target, z_sample)
    p_y = att_np.decoder(batch.target_x, z_sample.to(device))
    mu = p_y.mean
    # Plot predicted mean at each target point (note we could also
    # sample from distribution but plot mean for simplicity)
    plt.plot(batch.target_x.cpu().numpy()[0], mu.cpu().detach().numpy()[0], 
             c='b', alpha=0.5)
# Out:
# tensor([[[-0.0400],
#          [-0.0400],
#          [-0.0400],
#          [-0.0400],
#          [-0.0400],
#          [-0.0400],
#          [-0.0400],
#          [-0.0400],
#          [-0.0399],
#          [-0.0399],
#          [-0.0399],
#          [-0.0399],
#          [-0.0399],
#          [-0.0399],
#          [-0.0398],
#          [-0.0398],
#          [-0.0398],
#          [-0.0398],
#          [-0.0398],
#          [-0.0398],
#          [-0.0398],
#          [-0.0397],
#          [-0.0397],
#          [-0.0397],
#          [-0.0397],
#          [-0.0397],
#          [-0.0397],
#          [-0.0397],
#          [-0.0396],
#          [-0.0396],
#          [-0.0396],
#          [-0.0396],
#          [-0.0396],
#          [-0.0396],
#          [-0.0396],
#          [-0.0395],
#          [-0.0395],
#          [-0.0395],
#          [-0.0395],
#          [-0.0395],
#          [-0.0395],
#          [-0.0394],
#          [-0.0394],
#          [-0.0394],
#          [-0.0394],
#          [-0.0394],
#          [-0.0394],
#          [-0.0393],
#          [-0.0393],
#          [-0.0393],
#          [-0.0393],
#          [-0.0393],
#          [-0.0393],
#          [-0.0393],
#          [-0.0392],
#          [-0.0392],
    h_size_enc_det=128,
    h_size_enc_know=128,
    h_size_agg=128,
    N_h_layers_dec=3,
    N_h_layers_enc_know_phi=2,
    N_h_layers_enc_know_rho=2,
    N_h_layers_enc_det=6,
    N_h_layers_agg=3
)
print(inf_model)
print(sum(p.numel() for p in inf_model.parameters() if p.requires_grad))

optimiser = torch.optim.Adam(inf_model.parameters(), lr=1e-3)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device {device}")
inf_model.to(device)

train_loss = []
for iter in range(10000+1):
    inf_model.training = True
    optimiser.zero_grad()

    batch = data.generate_batch(batch_size=16, device=device)
    knowledge = generate_knowledge(batch.a, batch.b, batch.c)
    p_y_pred, q_z_target, q_z_context = inf_model(batch.context_x, batch.context_y, knowledge, batch.target_x, batch.target_y)

    loss, log_p = loss_function(p_y_pred, batch.target_y, q_z_target, q_z_context)

    loss.backward()
    optimiser.step()
    train_loss.append(loss.item())

    if iter % 1000 == 0:
        print(f"Iter: {iter}, Loss {loss.item():.6f},") # NLL {nll:.6f}")
    if iter % 2000 == 0:
        inf_model.training = False
        batch = data.generate_batch(1, testing=True, device=inf_model.device)
        knowledge = generate_knowledge(batch.a, batch.b, batch.c)
        plot_predictive(inf_model, batch, knowledge=knowledge, save=False, iter=None)
        inf_model.training = True

plt.plot(train_loss, label='train_loss')
window = 50
plt.plot([sum(train_loss[i:i+window])/window for i in range(len(train_loss)-window)], label=f'train_loss_{window}_smooth')
plt.legend()
plt.show()
# Out:
# InformedNeuralProcess(
#   (deterministic_encoder): DeterminisitcEncoder(
#     (deterministic_encoder): Sequential(
#       (0): Linear(in_features=2, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=128, out_features=128, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): ReLU()
#       (10): Linear(in_features=128, out_features=128, bias=True)
#       (11): ReLU()
#       (12): Linear(in_features=128, out_features=128, bias=True)
#       (13): Identity()
#     )
#   )
#   (knowledge_encoder): KnowledgeEncoder(
#     (phi): Sequential(
#       (0): Linear(in_features=4, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): Identity()
#     )
#     (rho): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): Identity()
#     )
#   )
#   (decoder): Decoder(
#     (xz_to_py): Sequential(
#       (0): Linear(in_features=129, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=128, out_features=2, bias=True)
#       (7): Identity()
#     )
#   )
#   (agg_mlp): Sequential(
#     (0): Linear(in_features=128, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=256, bias=True)
#     (7): Identity()
#   )
# )
# 315138
# Using device cuda:0
# Iter: 0, Loss 1.654760,
# Iter: 1000, Loss 1.004816,
# Iter: 2000, Loss 0.819161,
# Iter: 3000, Loss 0.699027,
# Iter: 4000, Loss 0.718966,
# Iter: 5000, Loss 0.527668,
# Iter: 6000, Loss 0.336174,
# Iter: 7000, Loss 0.337541,
# Iter: 8000, Loss 0.369124,
# Iter: 9000, Loss 0.075685,
# Iter: 10000, Loss -0.190456,

# %%
np_scores = []
for override_num_context in range(1, 21):
    np_test_score = evaluate(np_model, data, override_num_context=override_num_context, use_knowledge=False, batch_size=64)
    print(f"[NP] Num_context points: {override_num_context}, Test Loss: {np_test_score:.6f}")
    np_scores.append(np_test_score)

inf_scores = []
for override_num_context in range(1, 21):
    inf_test_score = evaluate(inf_model, data, override_num_context=override_num_context, use_knowledge=True, batch_size=64)
    print(f"[INP]: Num_context points: {override_num_context}, Test Loss: {inf_test_score:.6f}")
    inf_scores.append(inf_test_score)

plt.plot(range(1, 21), np_scores, "o-", label='NP')
plt.plot(range(1, 21), inf_scores, "o--", label='INP, knowledge=a')
plt.legend()
plt.show()
# Out:
# [NP] Num_context points: 1, Test Loss: -19.613810
# [NP] Num_context points: 2, Test Loss: -13.765142
# [NP] Num_context points: 3, Test Loss: -11.074625
# [NP] Num_context points: 4, Test Loss: -6.709089
# [NP] Num_context points: 5, Test Loss: -7.084566
# [NP] Num_context points: 6, Test Loss: -4.687437
# [NP] Num_context points: 7, Test Loss: -4.614048
# [NP] Num_context points: 8, Test Loss: -4.630173
# [NP] Num_context points: 9, Test Loss: -2.635783
# [NP] Num_context points: 10, Test Loss: -2.776935
# [NP] Num_context points: 11, Test Loss: -2.297745
# [NP] Num_context points: 12, Test Loss: -2.352884
# [NP] Num_context points: 13, Test Loss: -1.625952
# [NP] Num_context points: 14, Test Loss: -1.885280
# [NP] Num_context points: 15, Test Loss: -0.670694
# [NP] Num_context points: 16, Test Loss: -0.658828
# [NP] Num_context points: 17, Test Loss: -0.734276
# [NP] Num_context points: 18, Test Loss: -0.849096
# [NP] Num_context points: 19, Test Loss: -0.658041
# [NP] Num_context points: 20, Test Loss: -1.041951
# [INP]: Num_context points: 1, Test Loss: -12.606749
# [INP]: Num_context points: 2, Test Loss: -8.341799
# [INP]: Num_context points: 3, Test Loss: -4.783848
# [INP]: Num_context points: 4, Test Loss: -4.369560
# [INP]: Num_context points: 5, Test Loss: -3.883411
# [INP]: Num_context points: 6, Test Loss: -2.642409
# [INP]: Num_context points: 7, Test Loss: -1.982838
# [INP]: Num_context points: 8, Test Loss: -1.566753
# [INP]: Num_context points: 9, Test Loss: -1.456583
# [INP]: Num_context points: 10, Test Loss: -1.846650
# [INP]: Num_context points: 11, Test Loss: -1.226188
# [INP]: Num_context points: 12, Test Loss: -1.155411
# [INP]: Num_context points: 13, Test Loss: -0.587549
# [INP]: Num_context points: 14, Test Loss: -0.711422
# [INP]: Num_context points: 15, Test Loss: -0.675155
# [INP]: Num_context points: 16, Test Loss: -0.579318
# [INP]: Num_context points: 17, Test Loss: -0.889383
# [INP]: Num_context points: 18, Test Loss: -0.350124
# [INP]: Num_context points: 19, Test Loss: -0.294643
# [INP]: Num_context points: 20, Test Loss: -0.112361
